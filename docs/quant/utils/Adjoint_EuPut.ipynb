# %%
import numpy as np
import utils.optlib as opt
import plotly.graph_objects as go
import numba as nb

# %%
# setting the underlying
stock = opt.Underlying(price=65, volatility=0.3, interest=0.1)
stock_ = opt.Underlying(price=65, volatility=0.303, interest=0.1)

# creating the European Put option
EuPut = opt.Option(underlying=stock, style="European", call=False, strike=50)
EuPut_ = opt.Option(underlying=stock_, style="European", call=False, strike=50)

# creating the grid and adding option's parameters
grid0 = opt.Grid(xSteps=300, tSteps=200, xLeft=-3.0, xRight=3.0)
grid0.addOption(EuPut)
grid0.setBoundsPut()

grid_ = opt.Grid(xSteps=300, tSteps=200, xLeft=-3.0, xRight=3.0)
grid_.addOption(EuPut_)
grid_.setBoundsPut()

# %%
# creating matrices for schemes
@nb.njit()
def get_matricies(n, c):
    A = np.diag(np.ones(n+1) * (1 + c))
    B = np.diag(np.ones(n+1) * (1 - c))
    for i in range(1, n + 1):
        A[i, i-1] = -c/2
        A[i-1, i] = -c/2
        B[i, i-1] = c/2
        B[i-1, i] = c/2
    A[0,0] = 1
    A[n,n] = 1
    A[0,1] = 0
    A[n,n-1] = 0
    B[0,0] = 1
    B[n,n] = 1
    B[0,1] = 0
    B[n,n-1] = 0
    return A, B

# crank-nickolson scheme
def cn_scheme(grid: opt.Grid):
    A, B = get_matricies(grid0.xSteps, grid0.lamda)

    net = grid.net.copy()
    for i in np.arange(0, grid.tSteps):
        # explicit step
        f = np.dot(B, net[:, i].copy())
        # implicit step
        solution = opt.scalar_walk(A, f)
        net[:, i + 1] = solution

    grid.net = net.copy()
    return grid

# %% [markdown]
# ### Vega with Finite Differencies

# %%
grid0 = cn_scheme(grid0)
grid_ = cn_scheme(grid_)
net0 = grid0.net
net_ = grid_.net
vega = (net0[250:,:] - net_[250:,:]) / (stock.volatility - stock_.volatility)

grid_.net = vega
grid_.plot(0, cut=False)
# Out:
# <div>                            <div id="e5b75d18-606b-4d87-b1d3-5a981238faf6" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5b75d18-606b-4d87-b1d3-5a981238faf6")) {                    Plotly.newPlot(                        "e5b75d18-606b-4d87-b1d3-5a981238faf6",                        [{"x":[0.0,0.0002295225,0.000459045,0.0006885675,0.00091809,0.0011476125,0.001377135,0.0016066575,0.00183618,0.0020657025,0.002295225,0.0025247475,0.00275427,0.0029837925,0.003213315,0.0034428375,0.00367236,0.0039018825,0.004131405,0.0043609275,0.00459045,0.0048199725,0.005049495,0.0052790175,0.00550854,0.0057380625,0.005967585,0.0061971075,0.00642663,0.0066561525,0.006885675,0.0071151975,0.00734472,0.0075742425,0.007803765,0.0080332875,0.00826281,0.0084923325,0.008721855,0.0089513775,0.0091809,0.0094104225,0.009639945,0.0098694675,0.01009899,0.0103285125,0.010558035,0.0107875575,0.01101708,0.0112466025,0.011476125,0.0117056475,0.01193517,0.0121646925,0.012394215,0.0
.44,-1.42,-1.4,-1.38,-1.3599999999999999,-1.3399999999999999,-1.32,-1.3,-1.28,-1.26,-1.24,-1.22,-1.2,-1.18,-1.16,-1.14,-1.1199999999999999,-1.0999999999999999,-1.08,-1.06,-1.04,-1.02,-1.0,-0.98,-0.96,-0.94,-0.9199999999999999,-0.8999999999999999,-0.8799999999999999,-0.8599999999999999,-0.8399999999999999,-0.8199999999999998,-0.7999999 ...

# %% [markdown]
# ### Forward $y(x, \tau)$ and $dy/d\sigma$ computation

# %%
# for Vega
A, B = get_matricies(grid0.xSteps, grid0.lamda)

N = grid0.tSteps
M = grid0.xSteps
A_inv = np.linalg.inv(A)
Vega = np.empty((M+1, N+1))

def Y_sigma(time_ind, x_array):
    x = x_array[0]
    t = grid0.tGrid[time_ind]
    coef = -2 * stock.interest / stock.volatility**3

    y_sigma = coef * np.multiply(net0[:,0],  x_array)
    y_sigma[0] = coef * opt.g_func(grid0.q, t, x) * (x + (grid0.q + 1) * t)
    return y_sigma

lambda_sigma = stock.volatility * grid0.option.maturity * (M+1)**2 / ((N+1) * (grid0.xRight - grid0.xLeft)**2)
A_sigma = np.diag(2 * np.ones(M+1))
for i in range(1, M + 1):
    A[i, i-1] = -1
    A[i-1, i] = -1
A_sigma = A_sigma * lambda_sigma / 2
A_sigma[0,0] = 0
A_sigma[M,M] = 0
A_sigma[0,1] = 0
A_sigma[M,M-1] = 0

B_sigma = -A_sigma

# %%
# fwd vega calculation
Vega[:,0] = Y_sigma(0, grid0.xGrid.copy())

for i in np.arange(0, grid0.tSteps):
    Vega[:,i+1] = np.dot(A_inv, B_sigma @ net0[:,i] - A_sigma @ net0[:,i+1] + B @ Vega[:,i])

# %%
vega_grid = opt.Grid(xSteps=300,
                tSteps=200,
                xLeft=-3.0,
                xRight=3.0)

vega_grid.addOption(EuPut)
vega_grid.net = Vega[:250,:]
# vega_grid.toNormal(obj_mutation=True)
vega_grid.plot(0, cut=False, border=0.05)
# Out:
# <div>                            <div id="a4e3fa82-ae35-437a-8ddb-2cd6295945c6" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4e3fa82-ae35-437a-8ddb-2cd6295945c6")) {                    Plotly.newPlot(                        "a4e3fa82-ae35-437a-8ddb-2cd6295945c6",                        [{"x":[0.0,0.000225,0.00045,0.000675,0.0009,0.001125,0.00135,0.001575,0.0018,0.002025,0.00225,0.0024749999999999998,0.0027,0.002925,0.00315,0.003375,0.0036,0.003825,0.00405,0.004275,0.0045,0.004725,0.0049499999999999995,0.005175,0.0054,0.005625,0.00585,0.006075,0.0063,0.0065249999999999996,0.00675,0.006974999999999999,0.0072,0.007425,0.00765,0.007875,0.0081,0.008324999999999999,0.00855,0.008775,0.009,0.009225,0.00945,0.009675,0.009899999999999999,0.010125,0.01035,0.010575,0.0108,0.011025,0.01125,0.011474999999999999,
.06,-1.04,-1.02,-1.0,-0.98,-0.96,-0.94,-0.9199999999999999,-0.8999999999999999,-0.8799999999999999,-0.8599999999999999,-0.8399999999999999,-0.8199999999999998,-0.7999999999999998,-0.7799999999999998,-0.7599999999999998,-0.7399999999999998,-0.7199999999999998,-0.6999999999999997,-0.6800000000000002,-0.6600000000000001,-0.6400000000000001,-0.6200000000000001,-0.6000000000000001,-0.5800000000000001,-0.56,-0.54,-0.52,-0.5,-0.48,-0.45999999999999996,-0.43999999999999995,-0.41999999999999993,-0.3999999999999999,-0.3799999999999999,-0.3599999999999999,-0.33999999999999986,-0.31999999999999984,-0.2999999999 ...

# %% [markdown]
# ### Adjoint $\lambda^{T}$ computation (backward loop)

# %%
N = grid.tSteps
M = grid.xSteps

lambda_vec = np.empty((M+1, N+1))
lambda_vec[:,N] = np.ones(M+1)

A_inv = np.linalg.inv(A)
f_y = np.dot(A_inv, B)

for i in range(N, 1, -1):
    lambda_vec[:, i-1] = np.dot(f_y, lambda_vec[:,i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [201], in <cell line: 1>()
# ----> 1 N = grid.tSteps
#       2 M = grid.xSteps
#       4 lambda_vec = np.empty((M+1, N+1))
#
# NameError: name 'grid' is not defined

# %% [markdown]
# ### Adjoint Vega calculation (forward loop)

# %%
lambda_sigma = stock.volatility * grid.option.maturity * (M+1)**2 / ((N+1) * (grid.xRight - grid.xLeft)**2)
A_sigma = np.diag(2 * np.ones(M+1))
for i in range(1, M + 1):
    A[i, i-1] = -1
    A[i-1, i] = -1
A_sigma = A_sigma * lambda_sigma / 2
B_sigma = -A_sigma

# %%
Vega = np.empty((M+1, N+1))

x_vec =  grid.xGrid.copy()
y0_sigma = np.multiply(net[:,0], -2 * x_vec * stock.interest / stock.volatility**3)
Vega[:,0] = np.multiply(lambda_vec[:,0], y0_sigma)

def d_sigma(ind):
    x = grid.xGrid[0]
    t1 = grid.tGrid[ind]
    t2 = grid.tGrid[ind+1]
    q = grid.q

    el1 = opt.g_func(q, t1, x) + opt.g_func(q, t2, x)
    el2 = t1 * opt.g_func(q, t1, x) + t2 * opt.g_func(q, t2, x)

    d1 = el1 * lambda_sigma / 2
    d2 = (- 2 * stock.interest / stock.volatility**3) * (el1 * x + (q+1) * el2)
    return d1 + d2

# Adjoint vector of linear system
lambda_linear = np.dot(A_inv, np.ones(M+1))
for i in range(1, N+1):
    # linear system adjoint solving (finding foo_sigma)
    d_sigma_vec = np.zeros(M+1)
    d_sigma_vec[0] = d_sigma(i-1)
    something = B_sigma @ net[:,i-1] + B @ Vega[:,i-1] + d_sigma_vec - A_sigma @ net[:,i]
    foo_sigma = np.multiply(lambda_linear, something)

    Vega[:,i] = Vega[:,i-1] + np.multiply(lambda_vec[:,i], foo_sigma)

# %%
grid.net = Vega.copy()
grid.plot(0, cut=True)
